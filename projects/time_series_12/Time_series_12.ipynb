# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Привет, меня зовут Александр Куимов. Я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏 Надеюсь, тебя также не смутит, если я буду обращаться к тебе на "ты", но если это неудобно, обязательно скажи об этом!
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь реагировать на мои комментарии своими по шаблону, показанному чуть ниже. Это нужно, чтобы не создавалась путаница😉
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
#
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> В такой цветовой ячейке я прошу тебя оставлять свои комментарии. Если исправляешь проект на второй итерации и выше, не забывай пожалуйста указывать номер итерации, например, "Комментарий студента v.2".
# </div>
#
# <br/>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе датасаентистом. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Сделаем-все-необходимые-импорты" data-toc-modified-id="Сделаем-все-необходимые-импорты-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Сделаем все необходимые импорты</a></span></li><li><span><a href="#Подготовка" data-toc-modified-id="Подготовка-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка</a></span><ul class="toc-item"><li><span><a href="#Подготовим-данные" data-toc-modified-id="Подготовим-данные-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Подготовим данные</a></span></li><li><span><a href="#Функция-добавления-фичей" data-toc-modified-id="Функция-добавления-фичей-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Функция добавления фичей</a></span></li></ul></li><li><span><a href="#Анализ" data-toc-modified-id="Анализ-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ</a></span><ul class="toc-item"><li><span><a href="#Станционарный-ли-временной-ряд." data-toc-modified-id="Станционарный-ли-временной-ряд.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Станционарный ли временной ряд.</a></span></li><li><span><a href="#Проведем-исследование" data-toc-modified-id="Проведем-исследование-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Проведем исследование</a></span></li><li><span><a href="#Итоги-анализа" data-toc-modified-id="Итоги-анализа-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Итоги анализа</a></span></li></ul></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Обучение</a></span><ul class="toc-item"><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Линейная регрессия</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#CatBoost" data-toc-modified-id="CatBoost-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>CatBoost</a></span></li><li><span><a href="#Сравним-результаты-каждой-модели-на-кросс-валидации" data-toc-modified-id="Сравним-результаты-каждой-модели-на-кросс-валидации-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Сравним результаты каждой модели на кросс валидации</a></span></li><li><span><a href="#Итоги-обучения" data-toc-modified-id="Итоги-обучения-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Итоги обучения</a></span></li></ul></li><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Тестирование</a></span><ul class="toc-item"><li><span><a href="#проверим-catboost-на-тестовой-выборке" data-toc-modified-id="проверим-catboost-на-тестовой-выборке-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>проверим catboost на тестовой выборке</a></span></li><li><span><a href="#Визуализируем-результаты-предсказания" data-toc-modified-id="Визуализируем-результаты-предсказания-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Визуализируем результаты предсказания</a></span></li><li><span><a href="#Итоги-тестирования" data-toc-modified-id="Итоги-тестирования-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Итоги тестирования</a></span></li></ul></li><li><span><a href="#Подведение-итогов" data-toc-modified-id="Подведение-итогов-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Подведение итогов</a></span></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Постройте модель для такого предсказания.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# Вам нужно:
#
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.
#
#
# Данные лежат в файле `taxi.csv`. Количество заказов находится в столбце `num_orders` (от англ. *number of orders*, «число заказов»).

# %% [markdown]
# Нам предстоит проанализировать исторические данные о заказах такси в аэропортах дл якомпании "Четенькое такси", чтобы можно было привлекать больше такси в пиковые нагрузки. Чтобы спрогнозировать количество заказов на следующий час мы обучим несколько моделей и проверим какая работает лучше. Лучшую модель протестируем на тестовой выборке
#
# Работа будет включать в себя 8 важных этапов:
# - загрузка данных
# - изучение и подготовка данных
# - функция добавления фичей
# - анализ временного ряда
# - ресемплирование
# - обучение разных моделей
# - тестирование лучшей модели
# - подведение итогов

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Вижу твое добавленное описание проекта. Молодец! Это поможет тебе расставлять акценты в выводах

# %% [markdown]
# ## Сделаем все необходимые импорты

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from statsmodels.tsa.seasonal import seasonal_decompose

from sklearn.model_selection import train_test_split, TimeSeriesSplit
from sklearn.metrics import mean_squared_error

from sklearn.linear_model import LinearRegression

from sklearn.ensemble import RandomForestRegressor

from tqdm import tqdm

from catboost import CatBoostRegressor

# %% [markdown]
# ## Подготовка

# %% [markdown]
# Загрузим данные

# %%
df = pd.read_csv('/datasets/taxi.csv')
df.head()
# Out:
#               datetime  num_orders
# 0  2018-03-01 00:00:00           9
# 1  2018-03-01 00:10:00          14
# 2  2018-03-01 00:20:00          28
# 3  2018-03-01 00:30:00          20
# 4  2018-03-01 00:40:00          32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26496 entries, 0 to 26495
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    26496 non-null  object
#  1   num_orders  26496 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 414.1+ KB

# %% [markdown]
# Нужно будет заменить тип данных у datetime  и сделать индексиз этой колонки.

# %%
df.shape
# Out:
# (26496, 2)

# %% [markdown]
# ### Подготовим данные

# %% [markdown]
# Изменим тип данных на дату

# %%
df['datetime'] = df['datetime'].astype('datetime64')
df.dtypes
# Out:
# datetime      datetime64[ns]
# num_orders             int64
# dtype: object

# %% [markdown]
# сделаем дату индексом

# %%
df.index = df['datetime']

# %% [markdown]
# проведем ресемпл

# %%
df = df.resample('1H').sum()

# %%
df
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00         124
# 2018-03-01 01:00:00          85
# 2018-03-01 02:00:00          71
# 2018-03-01 03:00:00          66
# 2018-03-01 04:00:00          43
# ...                         ...
# 2018-08-31 19:00:00         136
# 2018-08-31 20:00:00         154
# 2018-08-31 21:00:00         159
# 2018-08-31 22:00:00         223
# 2018-08-31 23:00:00         205
#
# [4416 rows x 1 columns]

# %% [markdown]
# Проверим, что у нас правильно отсортированы даты

# %%
df.index.is_monotonic
# Out:
# True

# %% [markdown]
# даты расположены в правильном порядке

# %%
# df = df.drop('datetime',axis=1)
# df.head()

# %% [markdown]
# Увеличим количество признаков

# %%
df.head()
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00         124
# 2018-03-01 01:00:00          85
# 2018-03-01 02:00:00          71
# 2018-03-01 03:00:00          66
# 2018-03-01 04:00:00          43

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# С данными познакомились, проведен первичный аналитический осмотр!) Отлично, что проведено ресемплирование с использованием суммы. Полученная информация поможет нам в дальнейшем с предобработкой данных

# %% [markdown]
# ### Функция добавления фичей

# %%
def make_features(df, max_lag, rolling_size):
    df_copy = df.copy()
    
    cols = df_copy.columns[1:]
    df_copy = df_copy.drop(cols, axis=1)
#     print(df)
    
    # делаем календарные признаки
#     df['year'] = df.index.year эта фича не имеет смысла
    df_copy['month']= df.index.month
    df_copy['day'] = df.index.day
    df_copy['dayofweek'] = df.index.dayofweek
    df_copy['hour'] = df.index.hour
    df_copy['weekend'] = df_copy['dayofweek'] > 5
    df_copy['am'] = df_copy['hour'] < 12
    
    
    # делаем признаки отстающих значений
    for lag in range(1, max_lag+1):
        df_copy[f'lag_{str(lag)}'] = df_copy['num_orders'].shift(lag)
        
    # делаем признак скользящего среднего размером "rolling size"
    df_copy['rolling_mean'] = df_copy['num_orders'].shift().rolling(rolling_size).mean()
    
    # Добавляем разницу, которая будет целевым признаком
#     df['dif'] = df['num_orders'] - df['num_orders'].shift()
    
    return df_copy

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера  <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# признак 'diff' (разница между текущим и предыдущим значением) не может быть использован в обучающей выборке, он приводит к утечке. Если мы включим этот признак в обучающую выборку, то модель сможет без труда предсказать будущие значения на основе этого признака, что может привести к переобучению и неправильным прогнозам. Поэтому данный признак должен быть удален

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Принято, но этот признак был добавлен, так как сначала не получалось довести до нужного значения целевую метрику. Это был неудачный эксперимент, который как раз и привел к переобучению, но в дальнейшем я не использую этот признак при обучении.
#
#   Я удаляю признак при формировании выборок, но сейчас я **закомментировал добавление этой фичи**
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# При генерации новых признаков желательно написать функцию, чтобы она возвращала новый датафрейм, а не изменяла глобальную переменную.
#
# 1. Это хорошая практика (не изменять глобальные переменные внутри функции), которая улучшает читаемость кода.
# 2. В какой-то момент может появиться необходимость подбирать некоторые параметры используемый внутри функции. В этот момент копирование датасета станет обязательным.
#
#
#
#
# Для этого внутри, в начале функции нужно задать новое имя датафрейму с `df.copy()`, в нем создать новые признаки, а в конце функции возвращать через `return` этот датафрейм
# </div>

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Учел этот комментарий!
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %%
df_init = df.copy()

# %%
df = make_features(df, 1, 10)
df
# Out:
#                      num_orders  month  day  dayofweek  hour  weekend     am  \
# datetime
# 2018-03-01 00:00:00         124      3    1          3     0    False   True
# 2018-03-01 01:00:00          85      3    1          3     1    False   True
# 2018-03-01 02:00:00          71      3    1          3     2    False   True
# 2018-03-01 03:00:00          66      3    1          3     3    False   True
# 2018-03-01 04:00:00          43      3    1          3     4    False   True
# ...                         ...    ...  ...        ...   ...      ...    ...
# 2018-08-31 19:00:00         136      8   31          4    19    False  False
# 2018-08-31 20:00:00         154      8   31          4    20    False  False
# 2018-08-31 21:00:00         159      8   31          4    21    False  False
# 2018-08-31 22:00:00         223      8   31          4    22    False  False
# 2018-08-31 23:00:00         205      8   31          4    23    False  False
#
# ...

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
#
# Метрика на тесте должна быть ниже 48, поэтому стоит попробовать задать параметр max_lag равным 24 при создании новых признаков функцией. В случае заказов такси самая очевидная сезонность - внутри суток, а в сутках 24 часа, это значение и будет оптимальным

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Учел этот комментарий! Применю его далее при обучении
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# ## Анализ

# %% [markdown]
# Проанализируем данные
#
# Рассмотрим календарную неделю и какое количество заказов в час было в это время.

# %%
plt.figure(figsize=(10,10))
df['num_orders']['2018-03-06':'2018-03-12'].plot(grid=True, title='Количество заказов в час');

# %% [markdown]
# Добавим на график скользящее среднее

# %%
df[['num_orders','rolling_mean']]['2018-03-06':'2018-03-12'].plot(figsize=(10,10),grid=True,title='Количество заказов в час');

# %% [markdown]
# По графику можно заметить, что в середине ночью количетво заказов падает практически до нуля. Пик за день в большинстве дней находится во второй половине дня.
#
# Что-то большее сложно заметить, попробуем провести декомпозицию и что-то увидеть

# %%
decomposed = seasonal_decompose(df['num_orders'])

# %%
plt.figure(figsize=(10, 10))
plt.subplot(311)
decomposed.trend.plot(ax=plt.gca())
plt.title('Тренд за весе время исследования')


plt.subplot(312)
decomposed.seasonal['2018-03-01':'2018-03-31'].plot(ax=plt.gca())
plt.title('Сезонность за один месяц')


plt.subplot(313)
decomposed.resid['2018-03-01':'2018-03-31'].plot(ax=plt.gca())
plt.title('Шум за месяц')
plt.tight_layout()

# %%
decomposed.seasonal['2018-03-01':'2018-03-05'].plot(figsize=(15,10),ax=plt.gca(), title='seasonal');

# %% [markdown]
# Тренд к лету увеличивается, видимо все больше людей уезжают и приезжают откуда-то и заказывают такси в аэропорт.
#
# По графику сезонности можно заметить подверждение мысли о том, что к концу дня количество заказов увеличивается.

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Декомпозиция сделана верно. Хорошо, что сезонность была визуализирована на более коротком интервале)

# %% [markdown]
# ### Станционарный ли временной ряд.

# %% [markdown]
# Посмотрим на среднее и стандартное отклонение, чтобы понять стационарный ли ряд.

# %%
df
# Out:
#                      num_orders  month  day  dayofweek  hour  weekend     am  \
# datetime
# 2018-03-01 00:00:00         124      3    1          3     0    False   True
# 2018-03-01 01:00:00          85      3    1          3     1    False   True
# 2018-03-01 02:00:00          71      3    1          3     2    False   True
# 2018-03-01 03:00:00          66      3    1          3     3    False   True
# 2018-03-01 04:00:00          43      3    1          3     4    False   True
# ...                         ...    ...  ...        ...   ...      ...    ...
# 2018-08-31 19:00:00         136      8   31          4    19    False  False
# 2018-08-31 20:00:00         154      8   31          4    20    False  False
# 2018-08-31 21:00:00         159      8   31          4    21    False  False
# 2018-08-31 22:00:00         223      8   31          4    22    False  False
# 2018-08-31 23:00:00         205      8   31          4    23    False  False
#
# ...

# %%
data = df[['num_orders']]

data['rolling_mean'] = data.resample('12H').sum()['num_orders'].rolling(5).mean()

data['std'] = data.resample('12H').sum()['num_orders'].rolling(5).std()

data[['num_orders','rolling_mean','std']].resample('12H').sum()['2018-03-01':'2018-05-31'].plot(figsize=(20,10),grid=True,title='Проверка на тационарный ряд');
plt.show()

data[['num_orders','rolling_mean','std']].resample('12H').sum()['2018-05-31':'2018-08-31'].plot(figsize=(20,10),grid=True,title='Проверка на тационарный ряд');
# Out:
# /tmp/ipykernel_75/477954021.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['rolling_mean'] = data.resample('12H').sum()['num_orders'].rolling(5).mean()
# /tmp/ipykernel_75/477954021.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['std'] = data.resample('12H').sum()['num_orders'].rolling(5).std()

# %% [markdown]
#  <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера   <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# </b> Ячейка выше не отработала. Перед отправкой проекта стоит проверять работоспособность кода, причем именно на Платформе Практикума, а не локально - это можно сделать, нажав на панели Платформы Практикума (Jupiter Hub)
#
# `Kernel` и `Restart & Run All`. Исправь, пожалуйста.
#
# В этом требовании есть рациональное зерно. Согласись, если ты будешь презетновать свою работу на чужом компьютере (например руководителю), то не важно, работал ли проект у тебя на комьютере, он должен работать там, где ты будешь его запускать.
#
# В случае локального выполнения требуется обязательно использовать те версии библиотек, которые актуальны для  платформы Практикума. Еще при выполнении первых проектов ты ознакомился с "Рекомендациями по выполнению проектов", где сформулировано это правило, инструкция: « Установка окружения — как избежать конфликта версий библиотек»
#
# Ниже привожу вырезку из инструкции с актуальными версиями:
#
#     beautifulsoup4==4.9.3
#     matplotlib==3.3.4
#     nltk==3.6.1
#     numpy==1.20.1
#     pandas==1.2.4
#     plotly==5.4.0
#     psycopg2-binary==2.9.2
#     pymorphy2==0.9.1
#     pymorphy2-dicts==2.4.417127. 4579844
#     pymystem3==0.2.0
#     regex==2022.3.15
#     scikit-learn==0.24.1
#     scipy==1.8.0
#     seaborn==0.11.1
#     sqlalchemy==1.4.15
#     statsmodels==0.13.2
#     catboost==1.0.3
#     pyspark==3.0.2
#     torch==1.10.0
#     transformers==4.12.5
#     pillow==8.4.0
#     keras==2.7.0
#     tensorflow==2.7.0

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Исправил эту проблему! Не убрал здесь признак, который уже не существовал
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# ### Проведем исследование
# Попробуем рассмотреть как целевой признак разность между двумя часами, может это будет стационарным рядом.

# %%
df['dif'] = df['num_orders'] - df['num_orders'].shift()

# %%
df
# Out:
#                      num_orders  month  day  dayofweek  hour  weekend     am  \
# datetime
# 2018-03-01 00:00:00         124      3    1          3     0    False   True
# 2018-03-01 01:00:00          85      3    1          3     1    False   True
# 2018-03-01 02:00:00          71      3    1          3     2    False   True
# 2018-03-01 03:00:00          66      3    1          3     3    False   True
# 2018-03-01 04:00:00          43      3    1          3     4    False   True
# ...                         ...    ...  ...        ...   ...      ...    ...
# 2018-08-31 19:00:00         136      8   31          4    19    False  False
# 2018-08-31 20:00:00         154      8   31          4    20    False  False
# 2018-08-31 21:00:00         159      8   31          4    21    False  False
# 2018-08-31 22:00:00         223      8   31          4    22    False  False
# 2018-08-31 23:00:00         205      8   31          4    23    False  False
#
# ...

# %%
df['dif'].plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# Стандартное отклонение, почти не изменятеся, среднее не меняется, в общем будем использвать это как целевой признак

# %% [markdown]
# Удалим признак dif, чтобы не было утечки, так как он негативно повлияет на обучение.

# %%
df = df.drop('dif',axis=1)

# %% [markdown]
# ### Итоги анализа

# %% [markdown]
# Среднее увеличивается, значит этот ряд не является стационарным рядом. Но среднее меняется медленно, это может не сильно повлиять на предсказание.

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# df['dif'] нужно удалить после проведения EDA, так не будет утечки

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Исправил этот момент
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# ## Обучение

# %% [markdown]
# ### Линейная регрессия

# %% [markdown]
# Так как нам необходимо подобрать оптимальные параметры семплирования мы каждый раз подбором будем подбирать выборку

# %%
df.shape
# Out:
# (4416, 9)

# %%
# %%time
# best_lag = 0
# # lag_var = [int(i) for i in range(1, 7)]

# best_rolling = 0
# # rolling_size = [int(i) for i in range(2,10)]

# rmse_lin = 1000
# best_model_l = None



# for lag in range(1, 5):
#     for rolling in range(2,10):
#         df = make_features(df, lag, rolling)
        
#         train, test = train_test_split(df, test_size=0.1, shuffle=False, random_state=12345)
        
#         train = train.dropna(axis=0)
        
#         features_train, target_train = train.drop('num_orders',axis=1), train['num_orders']
#         features_test,  target_test  = test.drop('num_orders',axis=1),  test['num_orders']
        
        
#         tscv = TimeSeriesSplit(n_splits=3, test_size=2, gap=2)
#         for i, (train_index, test_index) in enumerate(tscv.split(features_test)):
#             print(f"Fold {i}:")
#             print(f"  Train: index={train_index}")
#             print(f"  Test:  index={test_index}")
        
        
        
#         model_l = LinearRegression()
        
#         model_l.fit(features_train, target_train)
        
#         predictions_l = model_l.predict(features_test)
        
#         rmse = mean_squared_error(predictions_l, target_test)**0.5
#         if rmse < rmse_lin:
#             rmse_lin = rmse
#             best_lag = lag
#             best_rolling=rolling
#             best_model_l = model_l
            
            
lag = 24
rolling = 7
df = make_features(df, lag, rolling)
            
train, test = train_test_split(df, test_size=0.1, shuffle=False, random_state=12345)
        
train = train.dropna(axis=0)

features_train, target_train = train.drop('num_orders',axis=1), train['num_orders']
features_test,  target_test  = test.drop('num_orders',axis=1),  test['num_orders'] 


cv_s_results_l = []

tscv = TimeSeriesSplit(n_splits=7, test_size=60, gap=7)
for i, (train_index, test_index) in enumerate(tscv.split(features_test)):
#     print(f"Fold {i}:")
#     print(f"  Train: index={train_index}")
#     print(f"  Test:  index={test_index}")
    
    model_l = LinearRegression()
        
    model_l.fit(features_train.iloc[train_index], target_train.iloc[train_index])

    predictions_l = model_l.predict(features_train.iloc[test_index])
    
    rmse_l_i = mean_squared_error( target_train.iloc[test_index], predictions_l, squared=False) 
    print(f"Fold {i}:")
    print(f'current rmse = {rmse_l_i}')
    cv_s_results_l.append(rmse_l_i)
    

    
# print(cv_s_results_l)
print()
cv_s_results_l = pd.Series(cv_s_results_l).mean()
            
print('RMSE кросс валидации линейной регрессии равен',cv_s_results_l)
# Out:
# Fold 0:
# current rmse = 31.04488681144854
# Fold 1:
# current rmse = 37.760765262644604
# Fold 2:
# current rmse = 27.31108393920938
# Fold 3:
# current rmse = 23.523710818071677
# Fold 4:
# current rmse = 18.179938451518044
# Fold 5:
# current rmse = 19.729895865502996
# Fold 6:
# current rmse = 22.998431523557823
#
# RMSE кросс валидации линейной регрессии равен 25.792673238850437
# CPU times: user 69.4 ms, sys: 43.3 ms, total: 113 ms
# Wall time: 83 ms

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Хорошо, что деление происходит последовательно по времени

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# При построении и поиске лучшей модели следует использовать один из предложенных вариантов:
#
# 1. Подбор гиперпараметров на валидационной выборке;
#
# 2. ИЛИ применение кросс-валидации  `grid.best_score_` - в этом случае не следует проверять модель на тесте. Это значит, что вместо обычного fit-predict следует использовать GridSearchCV или cross_val_score (если у модели гиперпараметры не подбираются), использовать атрибут `.best_score_` или `cross_val_score(..).mean()` для вывода метрики. На всякий случай предупрежу, что при работе с временными рядами не следует использовать стандартную кросс-валидацию, так как в определенный момент тренировочная выборка окажется позже валидационной. Для решения этой проблемы стоит использовать <a href="https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html">TimeSeriesSplit</a>. Объект этого типа нужно передать в параметр cv в метод основанный на кросс-валидации. Следует использовать метрику `neg_root_mean_squared_error`. Подать ее нужно внутрь `cross_val_score` и/или `SearchCV`, используя скорер `scoring=...`.  (это все касается каждого из экземпляров `cross_val_score` и/или `SearchCV`)

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Исправил это во всех моделях!
# </div>
#
# <br/>

# %% [markdown]
# ### Случайный лес

# %%
# %%time


# rmse_for = 1000

# best_lag = 0
# # lag_var = [int(i) for i in range(1, 7)]

# best_rolling = 0
# # rolling_size = [int(i) for i in range(2,10)]

# best_est = 0

# best_depth = 0
# depthes = [None]+[i for i in range(2,7)]
# for rolling in tqdm(range(2,10)):
#     for lag in range(1, 5):
#         for depth in depthes:
#             for est in range(10,121,25):

#                 df = make_features(df, lag, rolling)

#                 train, test = train_test_split(df, test_size=0.1, shuffle=False, random_state=12345)
#                 train = train.dropna(axis=0)

#                 features_train, target_train = train.drop('num_orders',axis=1), train['num_orders']
#                 features_test,  target_test  = test.drop('num_orders',axis=1),  test['num_orders']

#                 model_f = RandomForestRegressor(n_estimators=est, max_depth=depth, random_state=12345)

#                 model_f.fit(features_train, target_train)

#                 predictions_f = model_f.predict(features_test)

#                 rmse = mean_squared_error(predictions_f, target_test)**0.5
#                 if rmse < rmse_for:
#                     rmse_for = rmse
#                     best_lag = lag
#                     best_rolling=rolling
#                     best_est = est
#                     best_depth = depth
                    
                    
lag = 24
rolling = 7
df = make_features(df, lag, rolling)
            
train, test = train_test_split(df, test_size=0.1, shuffle=False, random_state=12345)
        
train = train.dropna(axis=0)

features_train, target_train = train.drop('num_orders',axis=1), train['num_orders']
features_test,  target_test  = test.drop('num_orders',axis=1),  test['num_orders'] 


cv_s_results_f = []

depthes = [None]+[i for i in range(2,7)]

tscv = TimeSeriesSplit(n_splits=7, test_size=60, gap=7)
for i, (train_index, test_index) in enumerate(tscv.split(features_test)):

    best_rmse = 1e300
    best_depth = -1
    best_est = -1
    
    
    for depth in depthes:
        for est in range(10,121,25):
            model_f = RandomForestRegressor(n_estimators=est, max_depth=depth, random_state=12345)

            model_f.fit(features_train.iloc[train_index], target_train.iloc[train_index])

            predictions_f = model_f.predict(features_train.iloc[test_index])

            rmse_f_i_curr = mean_squared_error( target_train.iloc[test_index], predictions_f, squared=False) 
            
            if rmse_f_i_curr < best_rmse:
                best_rmse = rmse_f_i_curr
                best_depth = depth
                best_est = est 
            
            
    print(f"Fold {i}:")
    
    print(f'Лучшее значение rmse после подбора гиперпараметров для {i} фолда = {best_rmse}')
    cv_s_results_f.append(best_rmse)
    

    
# print(cv_s_results_l)
# Out:
# Fold 0:
# Лучшее значение rmse после подбора гиперпараметров для 0 фолда = 26.631016055375607
# Fold 1:
# Лучшее значение rmse после подбора гиперпараметров для 1 фолда = 18.326840883899337
# Fold 2:
# Лучшее значение rmse после подбора гиперпараметров для 2 фолда = 19.65673206935116
# Fold 3:
# Лучшее значение rmse после подбора гиперпараметров для 3 фолда = 20.610621025919478
# Fold 4:
# Лучшее значение rmse после подбора гиперпараметров для 4 фолда = 14.673160173479468
# Fold 5:
# Лучшее значение rmse после подбора гиперпараметров для 5 фолда = 17.953347208813195
# Fold 6:
# Лучшее значение rmse после подбора гиперпараметров для 6 фолда = 17.938192783292816
# CPU times: user 23.5 s, sys: 145 ms, total: 23.6 s
# Wall time: 23.7 s

# %%
print()
cv_s_results_f = pd.Series(cv_s_results_f).mean()
            
print('RMSE кросс валидации случайного леса равен',cv_s_results_f)
# Out:
# RMSE кросс валидации случайного леса равен 19.398558600018728

# %%
# print('rmse на тестовой выборке равно',str(rmse_for),f'с параметрами: количество деревьев {best_est}, глубина деревьев {best_depth}')
# print('Лушчие параметры семплинга. Лаг',str(best_lag),', Размер скользящего окна',str(best_rolling))

# %% [markdown]
# ### CatBoost

# %% [markdown]
# CatBoost почему-то не хочет подбором рассматривать параметры датасета, поэтому попробуем руками

# %%
# %%time
# rmse_cat = 1e300

# cat_features = ['month', 'day', 'dayofweek', 'hour', 'weekend', 'am']


# for rolling in tqdm(range(2,10)):
#     for lag in range(1, 8):
#         df = make_features(df, lag, rolling)

#         train, test = train_test_split(df, test_size=0.1, shuffle=False, random_state=12345)
#         train = train.dropna(axis=0)

#         features_train, target_train = train.drop('num_orders',axis=1), train['num_orders']
#         features_test,  target_test  = test.drop('num_orders',axis=1),  test['num_orders']


#         model_cat = CatBoostRegressor(iterations=500,learning_rate=0.15, loss_function='RMSE')

#         model_cat.fit(features_train, target_train,cat_features=None,verbose=600)
# #         print(features_train.dtypes, features_valid.columns)

#         predictions_cat = model_cat.predict(features_test)

#         rmse = mean_squared_error(predictions_cat, target_test)**0.5
#         if rmse < rmse_cat:
#             rmse_cat = rmse
#             best_lag =  lag
#             best_rolling= rolling
        
# print('rmse', rmse_cat)

lag = 24
rolling = 7
df = make_features(df, lag, rolling)
            
train, test = train_test_split(df, test_size=0.1, shuffle=False, random_state=12345)
        
train = train.dropna(axis=0)

features_train, target_train = train.drop('num_orders',axis=1), train['num_orders']
features_test,  target_test  = test.drop('num_orders',axis=1),  test['num_orders'] 


cv_s_results_cat = []


cat_features = ['month', 'day', 'dayofweek', 'hour', 'weekend', 'am']


tscv = TimeSeriesSplit(n_splits=7, test_size=60, gap=7)
for i, (train_index, test_index) in enumerate(tscv.split(features_test)):
    
    model_cat = CatBoostRegressor(iterations=500,learning_rate=0.15, loss_function='RMSE')

    model_cat.fit(features_train.iloc[train_index], target_train.iloc[train_index],cat_features=cat_features,verbose=False)

    predictions_cat = model_cat.predict(features_train.iloc[test_index])
    
    rmse_cat_i = mean_squared_error( target_train.iloc[test_index], predictions_cat, squared=False) 
    print(f"Fold {i}:")
    print(f'current rmse = {rmse_cat_i}')
    cv_s_results_cat.append(rmse_cat_i)
    

    
# print(cv_s_results_l)
print()
cv_s_results_cat = pd.Series(cv_s_results_cat).mean()
            
print('RMSE кросс валидации catboostа равен',cv_s_results_cat)
# Out:
# Fold 0:
# current rmse = 26.743436019952696
# Fold 1:
# current rmse = 19.873191847909233
# Fold 2:
# current rmse = 19.785188277214278
# Fold 3:
# current rmse = 22.75456285491312
# Fold 4:
# current rmse = 14.785452763347376
# Fold 5:
# current rmse = 17.68545126558254
# Fold 6:
# current rmse = 17.462543492690717
#
# RMSE кросс валидации catboostа равен 19.869975217372854
# CPU times: user 9.56 s, sys: 588 ms, total: 10.2 s
# Wall time: 16.2 s

# %%
# print('rmse catboosta на тестовой выборке равно',str(rmse_cat))
# print('Лушчие параметры семплинга. Лаг',str(best_lag),', Размер скользящего окна',str(best_rolling))

# %% [markdown]
# ### Сравним результаты каждой модели на кросс валидации

# %%
print(f'RMSE Линейной регрессии на кросс-валидации равен {cv_s_results_l}')
print()
print(f'RMSE Случайного леса на кросс-валидации равен {cv_s_results_f}')
print()
print(f'RMSE CatBoost на кросс-валидации равен {cv_s_results_cat}')
print()
# Out:
# RMSE Линейной регрессии на кросс-валидации равен 25.792673238850437
#
# RMSE Случайного леса на кросс-валидации равен 19.398558600018728
#
# RMSE CatBoost на кросс-валидации равен 19.869975217372854

# %% [markdown]
# ###  Итоги обучения

# %% [markdown]
# Мы обучи несколько моделей, посмотрели их качество, было решено для финальной проверки выбрать модель catboost, потому что она хорошо себя показала и она может показать какие фичи самые важные
#
# Модель обучили, проверили на тестовых данных, в итоге целевая метрика rmse стала равна примерно 43, что приемлемый для нас результат.

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Молодец, что пробуешь разные модели в этом шаге)
# </div>

# %% [markdown]
# ## Тестирование

# %% [markdown]
# ### проверим catboost на тестовой выборке

# %%
df.columns
# Out:
# Index(['num_orders', 'month', 'day', 'dayofweek', 'hour', 'weekend', 'am',
#        'lag_1', 'lag_2', 'lag_3', 'lag_4', 'lag_5', 'lag_6', 'lag_7', 'lag_8',
#        'lag_9', 'lag_10', 'lag_11', 'lag_12', 'lag_13', 'lag_14', 'lag_15',
#        'lag_16', 'lag_17', 'lag_18', 'lag_19', 'lag_20', 'lag_21', 'lag_22',
#        'lag_23', 'lag_24', 'rolling_mean'],
#       dtype='object')

# %%
# %%time
df = make_features(df, 4, 5)

cat_features = ['month', 'day', 'dayofweek', 'hour', 'weekend', 'am']


train, test = train_test_split(df, test_size=0.1, shuffle=False, random_state=12345)
train = train.dropna(axis=0)

features_train, target_train = train.drop(['num_orders'],axis=1), train['num_orders']
features_test,  target_test  = test.drop(['num_orders'],axis=1),  test['num_orders']

model_cat = CatBoostRegressor(iterations=300, loss_function='RMSE')

model_cat.fit(features_train, target_train,cat_features=cat_features,verbose=False,plot=True)

predictions_cat_test = model_cat.predict(features_test)

rmse_cat_test = mean_squared_error(predictions_cat_test, target_test,squared=False)
print('rmse модели catboost на тестовой выборке', rmse_cat_test)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# rmse модели catboost на тестовой выборке 42.79538213385173
# CPU times: user 1.41 s, sys: 64.2 ms, total: 1.48 s
# Wall time: 2.31 s

# %%
pd.DataFrame(model_cat.get_feature_importance(),features_train.columns).plot(kind='barh', figsize=(15,10), grid=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Визуализируем результаты предсказания

# %%
visual_2 = pd.DataFrame(predictions_cat_test,columns=['preds'],index=test.index)
visual_2
# Out:
#                           preds
# datetime
# 2018-08-13 14:00:00  111.058956
# 2018-08-13 15:00:00  122.918027
# 2018-08-13 16:00:00  166.046444
# 2018-08-13 17:00:00  147.536148
# 2018-08-13 18:00:00  108.850996
# ...                         ...
# 2018-08-31 19:00:00  146.504054
# 2018-08-31 20:00:00  170.169890
# 2018-08-31 21:00:00  152.253430
# 2018-08-31 22:00:00  174.814464
# 2018-08-31 23:00:00  182.156708
#
# [442 rows x 1 columns]

# %%
visual = test['num_orders']
visual = pd.concat([visual,visual_2], axis=1)
visual
# Out:
#                      num_orders       preds
# datetime
# 2018-08-13 14:00:00         102  111.058956
# 2018-08-13 15:00:00         175  122.918027
# 2018-08-13 16:00:00         144  166.046444
# 2018-08-13 17:00:00         152  147.536148
# 2018-08-13 18:00:00         104  108.850996
# ...                         ...         ...
# 2018-08-31 19:00:00         136  146.504054
# 2018-08-31 20:00:00         154  170.169890
# 2018-08-31 21:00:00         159  152.253430
# 2018-08-31 22:00:00         223  174.814464
# 2018-08-31 23:00:00         205  182.156708
#
# [442 rows x 2 columns]

# %%
visual.resample('1H').sum().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# по графику мы видим, что наши предсказания достаточно точно предсказывают спрос на такси

# %% [markdown]
# ### Итоги тестирования

# %% [markdown]
# График важности фичей, полученный с помощью метода get_feature_importance(), который встроен в catboost, показывает, что признак времени является самым важным, он дает основные знания.
#
# Вероятно, это связано с сезонностью внутри дня. Это понятно, потому что спрос на такси в 5 утра будет меньше чем в 6 вечера

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# В конце проекта желательно визуализировать результаты (построить 2 временных ряда на одном графике), показать предсказанные значения лучшей модели и реальные тестовые

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b>Исправил!
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# ## Подведение итогов

# %% [markdown]
# Нам предстояло проанализировать исторические данные о заказах такси в аэропортах дл якомпании "Четенькое такси", чтобы можно было привлекать больше такси в пиковые нагрузки. Чтобы спрогнозировать количество заказов на следующий час мы обучили несколько моделей и проверили какая работает лучше. Такой оказалась модель catboost, ее результаты и функционал показали, что она это стоящий выбор. Лучшую модель протестировали на тестовой выборке, она показала метрику rmse равную 43.
#
#
# Работа будет включила в себя 8 важных этапов:
# - загрузка данных
# - изучение и подготовка данных
# - функция добавления фичей
# - анализ временного ряда
# - ресемплирование
# - обучение разных моделей
# - тестирование лучшей модели
# - подведение итогов

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера <a class="tocSkip"> </h2>
#
#
# У меня сложилось хорошее общее впечатление о проекте, тебе удалось неплохо справиться с этим проектом. Молодец! Подготовлены данные для анализа, изучен каждый параметр. Все красиво визуализировано, построено несколько моделей регрессии и оценено их качество. Осмысленная аналитика и дельная модельная работа - многое удалось как надо)
#
# Отмечу отдельные положительные моменты проекта🙂:
#
# - в ходе проекта встречались  функции, помогающие избавиться от дублирования кода;
# - много красивых визуализаций в проекте и хорошая интерпретация;
# - при обучении моделей использована валидация и поиск гиперпараметров.
#
# Есть несколько моментов всего, на которые стоит ещё раз взглянуть, я указал их в моих комментариях по ходу проекта. Предлагаю тебе доработать проект по моим комментариям, чтобы довести его до совершенства.
#
#
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
#
#
# Теперь почти идеально. Принимаю работу)
#
# Если хочешь лучше разобраться в теме, то могу посоветовать тебе:
#
# Полезная лекция про временные ряды: https://www.youtube.com/watch?v=u433nrxdf5k
#
# Б.Б. Демешев - временные ряды https://disk.yandex.ru/i/LiDHB-B3A6Lz5A
#
# Базовое применение ARIMA - https://colab.research.google.com/drive/17RnG91Eq8JBKyxToNzvCvjibfxum-oPj?usp=sharing
#
# Канторович - Анализ временных рядов https://yadi.sk/i/IOkUOS3hTXf3gg
# https://facebook.github.io/prophet/
#
# https://facebook.github.io/prophet/docs/quick_start.html#python-api
#
# https://nbviewer.jupyter.org/github/miptgirl/habra_materials/blob/master/prophet/habra_data.ipynb
#
#
#
# В этом проекте были отработаны все моменты.
#
# Успехов тебе в следующем спринте!
#
# Рад был помочь тебе)
#
# </div>

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Данные загружены и подготовлены
# - [x]  Данные проанализированы
# - [x]  Модель обучена, гиперпараметры подобраны
# - [x]  Качество моделей проверено, выводы сделаны
# - [x]  Значение *RMSE* на тестовой выборке не больше 48
